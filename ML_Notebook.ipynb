# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
print("hello")
# Out:
# hello

# %%
print("how are you?")
# Out:
# how are you?

# %%
from matplotlib import pyplot as plt

# %%
import sys
import sklearn

print(sys.executable)
print(sklearn.__version__)
# Out:
# C:\Users\pushk\AppData\Local\Programs\Python\Python312\python.exe
# 1.9.0

# %%
import seaborn
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
x = np.linspace(0,2*np.pi, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)
plt.grid()
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Sine Function")
plt.show()

# %%
plt.plot(x, np.cos(x))
plt.grid()
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Cosine Function")
plt.show()
